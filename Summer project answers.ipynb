# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# # Name : Paras Rajput , Email = Pr8101999@gmail.com , Batch 2

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is 0A80-3FC4
#
#  Directory of D:\mysite\Codes\new project
#
# 09/14/2021  01:45 PM    <DIR>          .
# 09/14/2021  01:45 PM    <DIR>          ..
# 09/12/2021  12:30 PM    <DIR>          .ipynb_checkpoints
# 09/14/2021  01:43 PM             1,386 download.png
# 09/14/2021  01:44 PM             6,142 Screensnip.jpg
# 09/12/2021  12:39 PM           119,493 Summer project answers.ipynb
# 09/12/2021  11:19 AM         2,573,921 summer.csv
#                4 File(s)      2,700,942 bytes
#                3 Dir(s)  720,479,535,104 bytes free

# %%
df =  pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# # 1. In how many cities Summer Olympics is held so far?

# %%
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# # 3. Which sport is having most number of  Medals so far? (Top 5)

# %%
df['Sport'].value_counts()
# Out:
# Aquatics             4170
# Athletics            3638
# Rowing               2667
# Gymnastics           2307
# Fencing              1613
# Football             1497
# Hockey               1422
# Wrestling            1212
# Shooting             1150
# Sailing              1109
# Cycling              1105
# Basketball           1012
# Canoe / Kayak        1002
# Volleyball            994
# Handball              973
# Equestrian            939
# Boxing                894
# Weightlifting         593
# Judo                  491
# Baseball              335
# Archery               329
# Tennis                296
# Rugby                 192
# Modern Pentathlon     180
# Softball              180
# Badminton             144
# Table Tennis          144
# Taekwondo             112
# Tug of War             94
# Canoe                  81
# Polo                   66
# Lacrosse               59
# Golf                   30
# Ice Hockey             27
# Skating                27
# ...

# %%
data = df['Sport'].value_counts().head(5)
data
# Out:
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Sport, dtype: int64

# %%
data.plot(x = 'Sport' , y = 'freq' , kind = 'bar' , figsize = (5,5))
plt.show()

# %% [markdown]
# # 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
data = df[df['Medal'] == 'Gold']

# %%
data
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
data2 = data['Sport'].value_counts().head(5)
data2
# Out:
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Sport, dtype: int64

# %%
data2.plot(x = 'Sport' , y = 'freq' , kind = 'bar' , figsize = (5,5)) 
plt.show()

# %% [markdown]
# # 4. Which player has won most number of medals? (Top 5)

# %%
data3 = df['Athlete'].value_counts().head(5)
data3
# Out:
# PHELPS, Michael       22
# LATYNINA, Larisa      18
# ANDRIANOV, Nikolay    15
# ONO, Takashi          13
# SHAKHLIN, Boris       13
# Name: Athlete, dtype: int64

# %%
data3.plot(x = 'Athlete' , y = 'freq' , kind = 'bar' , figsize = (5,5))
plt.show()

# %% [markdown]
# # 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
data = df[df['Medal'] == 'Gold']
data
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
data4 = data['Athlete'].value_counts().head(5)
data4
# Out:
# PHELPS, Michael     18
# SPITZ, Mark          9
# NURMI, Paavo         9
# LATYNINA, Larisa     9
# LEWIS, Carl          9
# Name: Athlete, dtype: int64

# %%
data4.plot(x = 'Athlete' , y = 'freq' , kind = 'bar' , figsize = (5,5))
plt.show()

# %% [markdown]
# # 6. In which year India won first Gold Medal in Summer Olympics?

# %%
data5 = df[(df['Country'] == 'IND') & (df['Medal'] == 'Gold')].sort_values(by = 'Year')
data5
# Out:
#        Year       City     Sport Discipline                   Athlete Country  \
# 5512   1928  Amsterdam    Hockey     Hockey      ALLEN, Richard James     IND
# 5526   1928  Amsterdam    Hockey     Hockey      YUSUF, Sayed Mohamed     IND
# 5525   1928  Amsterdam    Hockey     Hockey             SINGH, Jaipal     IND
# 5524   1928  Amsterdam    Hockey     Hockey              SHAUKAT, Ali     IND
# 5523   1928  Amsterdam    Hockey     Hockey       SEAMAN, Frederic S.     IND
# ...     ...        ...       ...        ...                       ...     ...
# 16088  1980     Moscow    Hockey     Hockey       AMARJIT RANA, Singh     IND
# 16087  1980     Moscow    Hockey     Hockey          ALLAN, Schofield     IND
# 16102  1980     Moscow    Hockey     Hockey              ZAFAR, Zafar     IND
# 16094  1980     Moscow    Hockey     Hockey  KAUSHIK, Maharaj Krishon     IND
# 28856  2008    Beijing  Shooting   Shooting           BINDRA, Abhinav     IND
#
# ...

# %%
data5.iloc[0]
# Out:
# Year                          1928
# City                     Amsterdam
# Sport                       Hockey
# Discipline                  Hockey
# Athlete       ALLEN, Richard James
# Country                        IND
# Gender                         Men
# Event                       Hockey
# Medal                         Gold
# Name: 5512, dtype: object

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# # 7. Which event is most popular in terms on number of players? (Top 5)

# %%
data6 = df['Event'].value_counts().head(5)
data6
# Out:
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Event, dtype: int64

# %%
data6.plot(x = 'Event' , y = 'freq' , kind = 'bar' , figsize = (5,5))
plt.show()

# %% [markdown]
# # 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
data7 = df[(df['Gender'] == 'Women') & (df['Medal'] == 'Gold')]
data7
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...

# %%
Final_data = data7['Sport'].value_counts().head(5)
Final_data
# Out:
# Aquatics      589
# Athletics     389
# Gymnastics    268
# Rowing        217
# Volleyball    166
# Name: Sport, dtype: int64

# %%
Final_data.plot(x = 'Sport' , y = 'freq' , kind = 'bar' , figsize = (5,5))
plt.plot()
# Out:
# []
